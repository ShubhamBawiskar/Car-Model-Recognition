# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO(r"D:\Augmented_Data\runs\detect\train\weights\last.pt")

# Define path to the image file
source = r"C:\Users\shubh\OneDrive\Desktop\Cars\multi3.jpg"

# Run inference on the source
results = model.predict(source, save=True, conf=0.5)
# Out:
# image 1/1 C:\Users\shubh\OneDrive\Desktop\Cars\multi3.jpg: 384x640 1 Fronx, 1 Nexon, 13.5ms
# Speed: 1.0ms preprocess, 13.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict2

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")  # load an official model
model = YOLO(r"D:\Augmented_Data\runs\detect\train\weights\last.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category

# %%
from ultralytics import YOLO

# Load a model
model = YOLO(r"D:\Augmented_Data\runs\detect\train\weights\best.pt")

# Validate with a custom dataset
metrics = model.val(data=r"D:\Augmented_Data\Merged_Data.yaml")
print(metrics.box.map)  # map50-95
# Out:
# Ultralytics YOLOv8.2.70  Python-3.9.18 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 168 layers, 3,390,113 parameters, 0 gradients, 9.9 GFLOPs
# val: Scanning D:\Augmented_Data\valid\labels.cache... 4621 images, 7 backgrounds, 0 corrupt: 100%|██████████| 4621/4621 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 289/289 [02:28<00:00,  1.94it/s]
#                    all       4621       4645        0.9      0.884      0.942      0.935
#               1-Series         12         12          1       0.47      0.691      0.686
#               2-Series         12         12      0.904       0.75      0.889      0.884
#               3-Series         14         14      0.974      0.357       0.75      0.747
#               5-Series         18         18      0.668      0.672      0.726      0.704
# ...
